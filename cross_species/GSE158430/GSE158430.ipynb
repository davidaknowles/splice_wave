# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path
import re
import sys
local_modules_path = (Path(".") / '..').resolve()
sys.path.append(str(local_modules_path))
from utils import merge_intervals

# %%
files = list(Path(".").glob("*.bed.gz"))
files
# Out:
# [PosixPath('GSM4799763_H3K27ac_Spleen_M22_Peaks.bed.gz'),
#  PosixPath('GSM4799624_ATAC_Liver_P350_Peaks.bed.gz'),
#  PosixPath('GSM4799620_ATAC_Hypothalamus_P350_Peaks.bed.gz'),
#  PosixPath('GSM4799752_H3K27ac_Lung_P348_Peaks.bed.gz'),
#  PosixPath('GSM4799622_ATAC_Liver_M22_Peaks.bed.gz'),
#  PosixPath('GSM4799726_H3K27ac_Cerebellum_M08_Peaks.bed.gz'),
#  PosixPath('GSM4799765_H3K27ac_Spleen_P350_Peaks.bed.gz'),
#  PosixPath('GSM4799606_ATAC_Adipose_M08_Peaks.bed.gz'),
#  PosixPath('GSM4799756_H3K27ac_Muscle_M08_Peaks.bed.gz'),
#  PosixPath('GSM4799610_ATAC_Cerebellum_M22_Peaks.bed.gz'),
#  PosixPath('GSM4799734_H3K27ac_Cortex_P348_Peaks.bed.gz'),
#  PosixPath('GSM4799761_H3K27ac_Spleen_B_Peaks.bed.gz'),
#  PosixPath('GSM4799636_ATAC_Spleen_P350_Peaks.bed.gz'),
#  PosixPath('GSM4799749_H3K27ac_Lung_B_Peaks.bed.gz'),
#  PosixPath('GSM4799739_H3K27ac_Hypothalamus_M22_Peaks.bed.gz'),
#  PosixPath('GSM4799744_H3K27ac_Liver_M08_Peaks.bed.gz'),
#  PosixPath('GSM4799628_ATAC_Lung_P350_Peaks.bed.gz'),
#  PosixPath('GSM4799635_ATAC_Spleen_P348_Peaks.bed.gz'),
#  PosixPath('GSM4799746_H3K27ac_Liver_P348_Peaks.bed.gz'),
#  PosixPath('GSM4799626_ATAC_Lung_M22_Peaks.bed.gz'),
#  PosixPath('GSM4799740_H3K27ac_Hypothalamus_P348_Peaks.bed.gz'),
#  PosixPath('GSM4799725_H3K27ac_Cerebellum_B_Peaks.bed.gz'),
#  PosixPath('GSM4799745_H3K27ac_Liver_M22_Peaks.bed.gz'),
#  PosixPath('GSM4799759_H3K27ac_Muscle_P350_Peaks.bed.gz'),
#  PosixPath('GSM4799733_H3K27ac_Cortex_M22_Peaks.bed.gz'),
#  PosixPath('GSM4799720_H3K27ac_Adipose_M08_Peaks.bed.gz'),
#  PosixPath('GSM4799758_H3K27ac_Muscle_P348_Peaks.bed.gz'),
#  PosixPath('GSM4799738_H3K27ac_Hypothalamus_M08_Peaks.bed.gz'),
#  PosixPath('GSM4799630_ATAC_Muscle_M22_Peaks.bed.gz'),
#  PosixPath('GSM4799722_H3K27ac_Adipose_P348_Peaks.bed.gz'),
#  PosixPath('GSM4799762_H3K27ac_Spleen_M08_Peaks.bed.gz'),
#  PosixPath('GSM4799619_ATAC_Hypothalamus_P348_Peaks.bed.gz'),
#  PosixPath('GSM4799718_H3K27ac_Adipose_A_Peaks.bed.gz'),
#  PosixPath('GSM4799724_H3K27ac_Cerebellum_A_Peaks.bed.gz'),
#  PosixPath('GSM4799735_H3K27ac_Cortex_P350_Peaks.bed.gz'),
#  PosixPath('GSM4799729_H3K27ac_Cerebellum_P350_Peaks.bed.gz'),
#  PosixPath('GSM4799743_H3K27ac_Liver_B_Peaks.bed.gz'),
#  PosixPath('GSM4799764_H3K27ac_Spleen_P348_Peaks.bed.gz'),
#  PosixPath('GSM4799623_ATAC_Liver_P348_Peaks.bed.gz'),
#  PosixPath('GSM4799750_H3K27ac_Lung_M08_Peaks.bed.gz'),
#  PosixPath('GSM4799727_H3K27ac_Cerebellum_M22_Peaks.bed.gz'),
#  PosixPath('GSM4799631_ATAC_Muscle_P348_Peaks.bed.gz'),
#  PosixPath('GSM4799732_H3K27ac_Cortex_M08_Peaks.bed.gz'),
#  PosixPath('GSM4799629_ATAC_Muscle_M08_Peaks.bed.gz'),
#  PosixPath('GSM4799723_H3K27ac_Adipose_P350_Peaks.bed.gz'),
#  PosixPath('GSM4799751_H3K27ac_Lung_M22_Peaks.bed.gz'),
#  PosixPath('GSM4799611_ATAC_Cerebellum_P348_Peaks.bed.gz'),
#  PosixPath('GSM4799616_ATAC_Cortex_P350_Peaks.bed.gz'),
#  PosixPath('GSM4799614_ATAC_Cortex_M22_Peaks.bed.gz'),
#  PosixPath('GSM4799627_ATAC_Lung_P348_Peaks.bed.gz'),
#  PosixPath('GSM4799618_ATAC_Hypothalamus_M22_Peaks.bed.gz'),
#  PosixPath('GSM4799753_H3K27ac_Lung_P350_Peaks.bed.gz'),
#  PosixPath('GSM4799737_H3K27ac_Hypothalamus_B_Peaks.bed.gz'),
#  PosixPath('GSM4799736_H3K27ac_Hypothalamus_A_Peaks.bed.gz'),
#  PosixPath('GSM4799609_ATAC_Adipose_P350_Peaks.bed.gz'),
#  PosixPath('GSM4799721_H3K27ac_Adipose_M22_Peaks.bed.gz'),
#  PosixPath('GSM4799728_H3K27ac_Cerebellum_P348_Peaks.bed.gz'),
#  PosixPath('GSM4799634_ATAC_Spleen_M22_Peaks.bed.gz'),
#  PosixPath('GSM4799621_ATAC_Liver_M08_Peaks.bed.gz'),
#  PosixPath('GSM4799633_ATAC_Spleen_M08_Peaks.bed.gz'),
#  PosixPath('GSM4799748_H3K27ac_Lung_A_Peaks.bed.gz'),
#  PosixPath('GSM4799741_H3K27ac_Hypothalamus_P350_Peaks.bed.gz'),
#  PosixPath('GSM4799755_H3K27ac_Muscle_B_Peaks.bed.gz'),
#  PosixPath('GSM4799613_ATAC_Cortex_M08_Peaks.bed.gz'),
#  PosixPath('GSM4799608_ATAC_Adipose_P348_Peaks.bed.gz'),
#  PosixPath('GSM4799760_H3K27ac_Spleen_A_Peaks.bed.gz'),
#  PosixPath('GSM4799632_ATAC_Muscle_P350_Peaks.bed.gz'),
#  PosixPath('GSM4799731_H3K27ac_Cortex_B_Peaks.bed.gz'),
#  PosixPath('GSM4799730_H3K27ac_Cortex_A_Peaks.bed.gz'),
#  PosixPath('GSM4799747_H3K27ac_Liver_P350_Peaks.bed.gz'),
#  PosixPath('GSM4799754_H3K27ac_Muscle_A_Peaks.bed.gz'),
#  PosixPath('GSM4799612_ATAC_Cerebellum_P350_Peaks.bed.gz'),
#  PosixPath('GSM4799615_ATAC_Cortex_P348_Peaks.bed.gz'),
#  PosixPath('GSM4799742_H3K27ac_Liver_A_Peaks.bed.gz'),
#  PosixPath('GSM4799617_ATAC_Hypothalamus_M08_Peaks.bed.gz'),
#  PosixPath('GSM4799757_H3K27ac_Muscle_M22_Peaks.bed.gz'),
#  PosixPath('GSM4799719_H3K27ac_Adipose_B_Peaks.bed.gz'),
#  PosixPath('GSM4799607_ATAC_Adipose_M22_Peaks.bed.gz'),
#  PosixPath('GSM4799625_ATAC_Lung_M08_Peaks.bed.gz')]

# %%
def get_meta(m): 
    return [ m.group(i) for i in [1,2,3] ]

matches = [ 
    get_meta(re.search(r"GSM\d+_(\w+)_([A-Za-z]+)_([A-Z])[0-9]*_Peaks\.bed\.gz", str(f)))
    for f in files ]
sample_meta = pd.DataFrame(matches, columns = ["assay", "tissue", "species"])
sample_meta["file"] = files
sample_meta
# Out:
#       assay        tissue species  \
# 0   H3K27ac        Spleen       M
# 1      ATAC         Liver       P
# 2      ATAC  Hypothalamus       P
# 3   H3K27ac          Lung       P
# 4      ATAC         Liver       M
# ..      ...           ...     ...
# 74     ATAC  Hypothalamus       M
# 75  H3K27ac        Muscle       M
# 76  H3K27ac       Adipose       B
# 77     ATAC       Adipose       M
# 78     ATAC          Lung       M
#
#                                               file
# 0       GSM4799763_H3K27ac_Spleen_M22_Peaks.bed.gz
# 1          GSM4799624_ATAC_Liver_P350_Peaks.bed.gz
# 2   GSM4799620_ATAC_Hypothalamus_P350_Peaks.bed.gz
# 3        GSM4799752_H3K27ac_Lung_P348_Peaks.bed.gz
# 4           GSM4799622_ATAC_Liver_M22_Peaks.bed.gz
# ..                                             ...
# 74   GSM4799617_ATAC_Hypothalamus_M08_Peaks.bed.gz
# 75      GSM4799757_H3K27ac_Muscle_M22_Peaks.bed.gz
# 76       GSM4799719_H3K27ac_Adipose_B_Peaks.bed.gz
# 77        GSM4799607_ATAC_Adipose_M22_Peaks.bed.gz
# 78           GSM4799625_ATAC_Lung_M08_Peaks.bed.gz
#
# [79 rows x 4 columns]

# %%
sample_meta["species"] = sample_meta["species"].map({
    "A" : "gallus_gallus", 
    "B" : "gallus_gallus", 
    "M" : "bos_taurus", 
    "P" : "sus_scrofa"
})
sample_meta
# Out:
#       assay        tissue        species  \
# 0   H3K27ac        Spleen     bos_taurus
# 1      ATAC         Liver     sus_scrofa
# 2      ATAC  Hypothalamus     sus_scrofa
# 3   H3K27ac          Lung     sus_scrofa
# 4      ATAC         Liver     bos_taurus
# ..      ...           ...            ...
# 74     ATAC  Hypothalamus     bos_taurus
# 75  H3K27ac        Muscle     bos_taurus
# 76  H3K27ac       Adipose  gallus_gallus
# 77     ATAC       Adipose     bos_taurus
# 78     ATAC          Lung     bos_taurus
#
#                                               file
# 0       GSM4799763_H3K27ac_Spleen_M22_Peaks.bed.gz
# 1          GSM4799624_ATAC_Liver_P350_Peaks.bed.gz
# 2   GSM4799620_ATAC_Hypothalamus_P350_Peaks.bed.gz
# 3        GSM4799752_H3K27ac_Lung_P348_Peaks.bed.gz
# 4           GSM4799622_ATAC_Liver_M22_Peaks.bed.gz
# ..                                             ...
# 74   GSM4799617_ATAC_Hypothalamus_M08_Peaks.bed.gz
# 75      GSM4799757_H3K27ac_Muscle_M22_Peaks.bed.gz
# 76       GSM4799719_H3K27ac_Adipose_B_Peaks.bed.gz
# 77        GSM4799607_ATAC_Adipose_M22_Peaks.bed.gz
# 78           GSM4799625_ATAC_Lung_M08_Peaks.bed.gz
#
# [79 rows x 4 columns]

# %%
unique = sample_meta[ ["assay", "tissue", "species"] ].drop_duplicates()
unique.shape
# Out:
# (40, 3)

# %%
import shutil
import time

column_names = [
    'chrom', 'start', 'end', 'name', 'score', 'strand',
    'signalValue', 'pValue', 'qValue', 'peak'
]
outdir = Path("merged")
outdir.mkdir(parents=True, exist_ok=True)

og_files = []
out_files = []
for i in range(unique.shape[0]):
    start_time = time.time()
    tissue = unique["tissue"].iloc[i]
    assay = unique["assay"].iloc[i]
    species = unique["species"].iloc[i]
    files = sample_meta.loc[ 
        (sample_meta["tissue"] == tissue) & 
        (sample_meta["assay"] == assay) & 
        (sample_meta["species"] == species), 
        "file"]
    outfile = f"{tissue}_{assay}_{species}.bed.gz"
    if False:
        df_all = pd.concat(
                    [ pd.read_csv(g, sep='\t', header=None, names=column_names) 
                     for g in files ],
                    axis=0)
        merged = merge_intervals(df_all)
        merged.to_csv(outdir / outfile, sep = "\t", index = False, header = False)
    out_files.append(outfile)
    og_files.append(",".join(files.astype(str)))
    print(f"{tissue} {assay} {species} done, took {time.time()-start_time}")
# Out:
# Spleen H3K27ac bos_taurus done, took 0.003409862518310547
# Liver ATAC sus_scrofa done, took 0.0020742416381835938
# Hypothalamus ATAC sus_scrofa done, took 0.002010822296142578
# Lung H3K27ac sus_scrofa done, took 0.0020160675048828125
# Liver ATAC bos_taurus done, took 0.0020067691802978516
# Cerebellum H3K27ac bos_taurus done, took 0.0020172595977783203
# Spleen H3K27ac sus_scrofa done, took 0.0019807815551757812
# Adipose ATAC bos_taurus done, took 0.0019326210021972656
# Muscle H3K27ac bos_taurus done, took 0.0019202232360839844
# Cerebellum ATAC bos_taurus done, took 0.001920938491821289
# Cortex H3K27ac sus_scrofa done, took 0.0019130706787109375
# Spleen H3K27ac gallus_gallus done, took 0.0019145011901855469
# Spleen ATAC sus_scrofa done, took 0.0018494129180908203
# Lung H3K27ac gallus_gallus done, took 0.001798391342163086
# Hypothalamus H3K27ac bos_taurus done, took 0.0017518997192382812
# Liver H3K27ac bos_taurus done, took 0.0017559528350830078
# Lung ATAC sus_scrofa done, took 0.0017855167388916016
# Liver H3K27ac sus_scrofa done, took 0.0017795562744140625
# Lung ATAC bos_taurus done, took 0.0017337799072265625
# Hypothalamus H3K27ac sus_scrofa done, took 0.0016508102416992188
# Cerebellum H3K27ac gallus_gallus done, took 0.0016698837280273438
# Muscle H3K27ac sus_scrofa done, took 0.0016655921936035156
# Cortex H3K27ac bos_taurus done, took 0.0016489028930664062
# Adipose H3K27ac bos_taurus done, took 0.001650094985961914
# Muscle ATAC bos_taurus done, took 0.0016434192657470703
# Adipose H3K27ac sus_scrofa done, took 0.0015857219696044922
# Adipose H3K27ac gallus_gallus done, took 0.0015888214111328125
# Cerebellum H3K27ac sus_scrofa done, took 0.0015931129455566406
# Liver H3K27ac gallus_gallus done, took 0.0015788078308105469
# Lung H3K27ac bos_taurus done, took 0.0016024112701416016
# Muscle ATAC sus_scrofa done, took 0.0016231536865234375
# Cerebellum ATAC sus_scrofa done, took 0.0015079975128173828
# Cortex ATAC sus_scrofa done, took 0.0015130043029785156
# Cortex ATAC bos_taurus done, took 0.0014944076538085938
# Hypothalamus ATAC bos_taurus done, took 0.001501321792602539
# Hypothalamus H3K27ac gallus_gallus done, took 0.0014865398406982422
# Adipose ATAC sus_scrofa done, took 0.0015048980712890625
# Spleen ATAC bos_taurus done, took 0.001505136489868164
# Muscle H3K27ac gallus_gallus done, took 0.0014514923095703125
# Cortex H3K27ac gallus_gallus done, took 0.0014178752899169922

# %%
unique["filename"] = out_files
unique["original"] = og_files
unique
# Out:
#       assay        tissue        species  \
# 0   H3K27ac        Spleen     bos_taurus
# 1      ATAC         Liver     sus_scrofa
# 2      ATAC  Hypothalamus     sus_scrofa
# 3   H3K27ac          Lung     sus_scrofa
# 4      ATAC         Liver     bos_taurus
# 5   H3K27ac    Cerebellum     bos_taurus
# 6   H3K27ac        Spleen     sus_scrofa
# 7      ATAC       Adipose     bos_taurus
# 8   H3K27ac        Muscle     bos_taurus
# 9      ATAC    Cerebellum     bos_taurus
# 10  H3K27ac        Cortex     sus_scrofa
# 11  H3K27ac        Spleen  gallus_gallus
# 12     ATAC        Spleen     sus_scrofa
# 13  H3K27ac          Lung  gallus_gallus
# 14  H3K27ac  Hypothalamus     bos_taurus
# 15  H3K27ac         Liver     bos_taurus
# 16     ATAC          Lung     sus_scrofa
# 18  H3K27ac         Liver     sus_scrofa
# 19     ATAC          Lung     bos_taurus
# 20  H3K27ac  Hypothalamus     sus_scrofa
# 21  H3K27ac    Cerebellum  gallus_gallus
# 23  H3K27ac        Muscle     sus_scrofa
# 24  H3K27ac        Cortex     bos_taurus
# 25  H3K27ac       Adipose     bos_taurus
# 28     ATAC        Muscle     bos_taurus
# 29  H3K27ac       Adipose     sus_scrofa
# 32  H3K27ac       Adipose  gallus_gallus
# 35  H3K27ac    Cerebellum     sus_scrofa
# 36  H3K27ac         Liver  gallus_gallus
# 39  H3K27ac          Lung     bos_taurus
# 41     ATAC        Muscle     sus_scrofa
# 46     ATAC    Cerebellum     sus_scrofa
# 47     ATAC        Cortex     sus_scrofa
# 48     ATAC        Cortex     bos_taurus
# 50     ATAC  Hypothalamus     bos_taurus
# 52  H3K27ac  Hypothalamus  gallus_gallus
# 54     ATAC       Adipose     sus_scrofa
# 57     ATAC        Spleen     bos_taurus
# 62  H3K27ac        Muscle  gallus_gallus
# 67  H3K27ac        Cortex  gallus_gallus
#
#                                      filename  \
# 0            Spleen_H3K27ac_bos_taurus.bed.gz
# 1                Liver_ATAC_sus_scrofa.bed.gz
# 2         Hypothalamus_ATAC_sus_scrofa.bed.gz
# 3              Lung_H3K27ac_sus_scrofa.bed.gz
# 4                Liver_ATAC_bos_taurus.bed.gz
# 5        Cerebellum_H3K27ac_bos_taurus.bed.gz
# 6            Spleen_H3K27ac_sus_scrofa.bed.gz
# 7              Adipose_ATAC_bos_taurus.bed.gz
# 8            Muscle_H3K27ac_bos_taurus.bed.gz
# 9           Cerebellum_ATAC_bos_taurus.bed.gz
# 10           Cortex_H3K27ac_sus_scrofa.bed.gz
# 11        Spleen_H3K27ac_gallus_gallus.bed.gz
# 12              Spleen_ATAC_sus_scrofa.bed.gz
# 13          Lung_H3K27ac_gallus_gallus.bed.gz
# 14     Hypothalamus_H3K27ac_bos_taurus.bed.gz
# 15            Liver_H3K27ac_bos_taurus.bed.gz
# 16                Lung_ATAC_sus_scrofa.bed.gz
# 18            Liver_H3K27ac_sus_scrofa.bed.gz
# 19                Lung_ATAC_bos_taurus.bed.gz
# 20     Hypothalamus_H3K27ac_sus_scrofa.bed.gz
# 21    Cerebellum_H3K27ac_gallus_gallus.bed.gz
# 23           Muscle_H3K27ac_sus_scrofa.bed.gz
# 24           Cortex_H3K27ac_bos_taurus.bed.gz
# 25          Adipose_H3K27ac_bos_taurus.bed.gz
# 28              Muscle_ATAC_bos_taurus.bed.gz
# 29          Adipose_H3K27ac_sus_scrofa.bed.gz
# 32       Adipose_H3K27ac_gallus_gallus.bed.gz
# 35       Cerebellum_H3K27ac_sus_scrofa.bed.gz
# 36         Liver_H3K27ac_gallus_gallus.bed.gz
# 39             Lung_H3K27ac_bos_taurus.bed.gz
# 41              Muscle_ATAC_sus_scrofa.bed.gz
# 46          Cerebellum_ATAC_sus_scrofa.bed.gz
# 47              Cortex_ATAC_sus_scrofa.bed.gz
# 48              Cortex_ATAC_bos_taurus.bed.gz
# 50        Hypothalamus_ATAC_bos_taurus.bed.gz
# 52  Hypothalamus_H3K27ac_gallus_gallus.bed.gz
# 54             Adipose_ATAC_sus_scrofa.bed.gz
# 57              Spleen_ATAC_bos_taurus.bed.gz
# 62        Muscle_H3K27ac_gallus_gallus.bed.gz
# 67        Cortex_H3K27ac_gallus_gallus.bed.gz
#
#                                              original
# 0   GSM4799763_H3K27ac_Spleen_M22_Peaks.bed.gz,GSM...
# 1   GSM4799624_ATAC_Liver_P350_Peaks.bed.gz,GSM479...
# 2   GSM4799620_ATAC_Hypothalamus_P350_Peaks.bed.gz...
# 3   GSM4799752_H3K27ac_Lung_P348_Peaks.bed.gz,GSM4...
# 4   GSM4799622_ATAC_Liver_M22_Peaks.bed.gz,GSM4799...
# 5   GSM4799726_H3K27ac_Cerebellum_M08_Peaks.bed.gz...
# 6   GSM4799765_H3K27ac_Spleen_P350_Peaks.bed.gz,GS...
# 7   GSM4799606_ATAC_Adipose_M08_Peaks.bed.gz,GSM47...
# 8   GSM4799756_H3K27ac_Muscle_M08_Peaks.bed.gz,GSM...
# 9         GSM4799610_ATAC_Cerebellum_M22_Peaks.bed.gz
# 10  GSM4799734_H3K27ac_Cortex_P348_Peaks.bed.gz,GS...
# 11  GSM4799761_H3K27ac_Spleen_B_Peaks.bed.gz,GSM47...
# 12  GSM4799636_ATAC_Spleen_P350_Peaks.bed.gz,GSM47...
# 13  GSM4799749_H3K27ac_Lung_B_Peaks.bed.gz,GSM4799...
# 14  GSM4799739_H3K27ac_Hypothalamus_M22_Peaks.bed....
# 15  GSM4799744_H3K27ac_Liver_M08_Peaks.bed.gz,GSM4...
# 16  GSM4799628_ATAC_Lung_P350_Peaks.bed.gz,GSM4799...
# 18  GSM4799746_H3K27ac_Liver_P348_Peaks.bed.gz,GSM...
# 19  GSM4799626_ATAC_Lung_M22_Peaks.bed.gz,GSM47996...
# 20  GSM4799740_H3K27ac_Hypothalamus_P348_Peaks.bed...
# 21  GSM4799725_H3K27ac_Cerebellum_B_Peaks.bed.gz,G...
# 23  GSM4799759_H3K27ac_Muscle_P350_Peaks.bed.gz,GS...
# 24  GSM4799733_H3K27ac_Cortex_M22_Peaks.bed.gz,GSM...
# 25  GSM4799720_H3K27ac_Adipose_M08_Peaks.bed.gz,GS...
# 28  GSM4799630_ATAC_Muscle_M22_Peaks.bed.gz,GSM479...
# 29  GSM4799722_H3K27ac_Adipose_P348_Peaks.bed.gz,G...
# 32  GSM4799718_H3K27ac_Adipose_A_Peaks.bed.gz,GSM4...
# 35  GSM4799729_H3K27ac_Cerebellum_P350_Peaks.bed.g...
# 36  GSM4799743_H3K27ac_Liver_B_Peaks.bed.gz,GSM479...
# 39  GSM4799750_H3K27ac_Lung_M08_Peaks.bed.gz,GSM47...
# 41  GSM4799631_ATAC_Muscle_P348_Peaks.bed.gz,GSM47...
# 46  GSM4799611_ATAC_Cerebellum_P348_Peaks.bed.gz,G...
# 47  GSM4799616_ATAC_Cortex_P350_Peaks.bed.gz,GSM47...
# 48  GSM4799614_ATAC_Cortex_M22_Peaks.bed.gz,GSM479...
# 50  GSM4799618_ATAC_Hypothalamus_M22_Peaks.bed.gz,...
# 52  GSM4799737_H3K27ac_Hypothalamus_B_Peaks.bed.gz...
# 54  GSM4799609_ATAC_Adipose_P350_Peaks.bed.gz,GSM4...
# 57  GSM4799634_ATAC_Spleen_M22_Peaks.bed.gz,GSM479...
# 62  GSM4799755_H3K27ac_Muscle_B_Peaks.bed.gz,GSM47...
# 67  GSM4799731_H3K27ac_Cortex_B_Peaks.bed.gz,GSM47...

# %%
meta = unique[["tissue","assay","species","filename","original"]]
meta.to_csv("meta.tsv", sep="\t", index=False)

# %%
meta
# Out:
#           tissue    assay        species  \
# 0         Spleen  H3K27ac     bos_taurus
# 1          Liver     ATAC     sus_scrofa
# 2   Hypothalamus     ATAC     sus_scrofa
# 3           Lung  H3K27ac     sus_scrofa
# 4          Liver     ATAC     bos_taurus
# 5     Cerebellum  H3K27ac     bos_taurus
# 6         Spleen  H3K27ac     sus_scrofa
# 7        Adipose     ATAC     bos_taurus
# 8         Muscle  H3K27ac     bos_taurus
# 9     Cerebellum     ATAC     bos_taurus
# 10        Cortex  H3K27ac     sus_scrofa
# 11        Spleen  H3K27ac  gallus_gallus
# 12        Spleen     ATAC     sus_scrofa
# 13          Lung  H3K27ac  gallus_gallus
# 14  Hypothalamus  H3K27ac     bos_taurus
# 15         Liver  H3K27ac     bos_taurus
# 16          Lung     ATAC     sus_scrofa
# 18         Liver  H3K27ac     sus_scrofa
# 19          Lung     ATAC     bos_taurus
# 20  Hypothalamus  H3K27ac     sus_scrofa
# 21    Cerebellum  H3K27ac  gallus_gallus
# 23        Muscle  H3K27ac     sus_scrofa
# 24        Cortex  H3K27ac     bos_taurus
# 25       Adipose  H3K27ac     bos_taurus
# 28        Muscle     ATAC     bos_taurus
# 29       Adipose  H3K27ac     sus_scrofa
# 32       Adipose  H3K27ac  gallus_gallus
# 35    Cerebellum  H3K27ac     sus_scrofa
# 36         Liver  H3K27ac  gallus_gallus
# 39          Lung  H3K27ac     bos_taurus
# 41        Muscle     ATAC     sus_scrofa
# 46    Cerebellum     ATAC     sus_scrofa
# 47        Cortex     ATAC     sus_scrofa
# 48        Cortex     ATAC     bos_taurus
# 50  Hypothalamus     ATAC     bos_taurus
# 52  Hypothalamus  H3K27ac  gallus_gallus
# 54       Adipose     ATAC     sus_scrofa
# 57        Spleen     ATAC     bos_taurus
# 62        Muscle  H3K27ac  gallus_gallus
# 67        Cortex  H3K27ac  gallus_gallus
#
#                                      filename  \
# 0            Spleen_H3K27ac_bos_taurus.bed.gz
# 1                Liver_ATAC_sus_scrofa.bed.gz
# 2         Hypothalamus_ATAC_sus_scrofa.bed.gz
# 3              Lung_H3K27ac_sus_scrofa.bed.gz
# 4                Liver_ATAC_bos_taurus.bed.gz
# 5        Cerebellum_H3K27ac_bos_taurus.bed.gz
# 6            Spleen_H3K27ac_sus_scrofa.bed.gz
# 7              Adipose_ATAC_bos_taurus.bed.gz
# 8            Muscle_H3K27ac_bos_taurus.bed.gz
# 9           Cerebellum_ATAC_bos_taurus.bed.gz
# 10           Cortex_H3K27ac_sus_scrofa.bed.gz
# 11        Spleen_H3K27ac_gallus_gallus.bed.gz
# 12              Spleen_ATAC_sus_scrofa.bed.gz
# 13          Lung_H3K27ac_gallus_gallus.bed.gz
# 14     Hypothalamus_H3K27ac_bos_taurus.bed.gz
# 15            Liver_H3K27ac_bos_taurus.bed.gz
# 16                Lung_ATAC_sus_scrofa.bed.gz
# 18            Liver_H3K27ac_sus_scrofa.bed.gz
# 19                Lung_ATAC_bos_taurus.bed.gz
# 20     Hypothalamus_H3K27ac_sus_scrofa.bed.gz
# 21    Cerebellum_H3K27ac_gallus_gallus.bed.gz
# 23           Muscle_H3K27ac_sus_scrofa.bed.gz
# 24           Cortex_H3K27ac_bos_taurus.bed.gz
# 25          Adipose_H3K27ac_bos_taurus.bed.gz
# 28              Muscle_ATAC_bos_taurus.bed.gz
# 29          Adipose_H3K27ac_sus_scrofa.bed.gz
# 32       Adipose_H3K27ac_gallus_gallus.bed.gz
# 35       Cerebellum_H3K27ac_sus_scrofa.bed.gz
# 36         Liver_H3K27ac_gallus_gallus.bed.gz
# 39             Lung_H3K27ac_bos_taurus.bed.gz
# 41              Muscle_ATAC_sus_scrofa.bed.gz
# 46          Cerebellum_ATAC_sus_scrofa.bed.gz
# 47              Cortex_ATAC_sus_scrofa.bed.gz
# 48              Cortex_ATAC_bos_taurus.bed.gz
# 50        Hypothalamus_ATAC_bos_taurus.bed.gz
# 52  Hypothalamus_H3K27ac_gallus_gallus.bed.gz
# 54             Adipose_ATAC_sus_scrofa.bed.gz
# 57              Spleen_ATAC_bos_taurus.bed.gz
# 62        Muscle_H3K27ac_gallus_gallus.bed.gz
# 67        Cortex_H3K27ac_gallus_gallus.bed.gz
#
#                                              original
# 0   GSM4799763_H3K27ac_Spleen_M22_Peaks.bed.gz,GSM...
# 1   GSM4799624_ATAC_Liver_P350_Peaks.bed.gz,GSM479...
# 2   GSM4799620_ATAC_Hypothalamus_P350_Peaks.bed.gz...
# 3   GSM4799752_H3K27ac_Lung_P348_Peaks.bed.gz,GSM4...
# 4   GSM4799622_ATAC_Liver_M22_Peaks.bed.gz,GSM4799...
# 5   GSM4799726_H3K27ac_Cerebellum_M08_Peaks.bed.gz...
# 6   GSM4799765_H3K27ac_Spleen_P350_Peaks.bed.gz,GS...
# 7   GSM4799606_ATAC_Adipose_M08_Peaks.bed.gz,GSM47...
# 8   GSM4799756_H3K27ac_Muscle_M08_Peaks.bed.gz,GSM...
# 9         GSM4799610_ATAC_Cerebellum_M22_Peaks.bed.gz
# 10  GSM4799734_H3K27ac_Cortex_P348_Peaks.bed.gz,GS...
# 11  GSM4799761_H3K27ac_Spleen_B_Peaks.bed.gz,GSM47...
# 12  GSM4799636_ATAC_Spleen_P350_Peaks.bed.gz,GSM47...
# 13  GSM4799749_H3K27ac_Lung_B_Peaks.bed.gz,GSM4799...
# 14  GSM4799739_H3K27ac_Hypothalamus_M22_Peaks.bed....
# 15  GSM4799744_H3K27ac_Liver_M08_Peaks.bed.gz,GSM4...
# 16  GSM4799628_ATAC_Lung_P350_Peaks.bed.gz,GSM4799...
# 18  GSM4799746_H3K27ac_Liver_P348_Peaks.bed.gz,GSM...
# 19  GSM4799626_ATAC_Lung_M22_Peaks.bed.gz,GSM47996...
# 20  GSM4799740_H3K27ac_Hypothalamus_P348_Peaks.bed...
# 21  GSM4799725_H3K27ac_Cerebellum_B_Peaks.bed.gz,G...
# 23  GSM4799759_H3K27ac_Muscle_P350_Peaks.bed.gz,GS...
# 24  GSM4799733_H3K27ac_Cortex_M22_Peaks.bed.gz,GSM...
# 25  GSM4799720_H3K27ac_Adipose_M08_Peaks.bed.gz,GS...
# 28  GSM4799630_ATAC_Muscle_M22_Peaks.bed.gz,GSM479...
# 29  GSM4799722_H3K27ac_Adipose_P348_Peaks.bed.gz,G...
# 32  GSM4799718_H3K27ac_Adipose_A_Peaks.bed.gz,GSM4...
# 35  GSM4799729_H3K27ac_Cerebellum_P350_Peaks.bed.g...
# 36  GSM4799743_H3K27ac_Liver_B_Peaks.bed.gz,GSM479...
# 39  GSM4799750_H3K27ac_Lung_M08_Peaks.bed.gz,GSM47...
# 41  GSM4799631_ATAC_Muscle_P348_Peaks.bed.gz,GSM47...
# 46  GSM4799611_ATAC_Cerebellum_P348_Peaks.bed.gz,G...
# 47  GSM4799616_ATAC_Cortex_P350_Peaks.bed.gz,GSM47...
# 48  GSM4799614_ATAC_Cortex_M22_Peaks.bed.gz,GSM479...
# 50  GSM4799618_ATAC_Hypothalamus_M22_Peaks.bed.gz,...
# 52  GSM4799737_H3K27ac_Hypothalamus_B_Peaks.bed.gz...
# 54  GSM4799609_ATAC_Adipose_P350_Peaks.bed.gz,GSM4...
# 57  GSM4799634_ATAC_Spleen_M22_Peaks.bed.gz,GSM479...
# 62  GSM4799755_H3K27ac_Muscle_B_Peaks.bed.gz,GSM47...
# 67  GSM4799731_H3K27ac_Cortex_B_Peaks.bed.gz,GSM47...
