# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path
import re
import sys
local_modules_path = (Path(".") / '..').resolve()
sys.path.append(str(local_modules_path))
from utils import merge_intervals

# %%
files = list(Path(".").glob("*.gz"))
files
# Out:
# [PosixPath('GSM5835477_ChIP_H3K27ac_HH18_PT_rep1.narrowPeak.gz'),
#  PosixPath('GSM6152758_ATAC_HH35_DS_rep1.narrowPeak.gz'),
#  PosixPath('GSM6152753_ATAC_E125_FB_rep2.narrowPeak.gz'),
#  PosixPath('GSM5835479_ChIP_H3K27ac_HH28_DFL_rep1.narrowPeak.gz'),
#  PosixPath('GSM6152759_ATAC_HH35_DS_rep2.narrowPeak.gz'),
#  PosixPath('GSM5835478_ChIP_H3K27ac_HH18_PT_rep2.narrowPeak.gz'),
#  PosixPath('GSM5835470_ChIP_H3K27ac_E125_DFL_rep1.narrowPeak.gz'),
#  PosixPath('GSM6152750_ATAC_E95_PT_rep1.narrowPeak.gz'),
#  PosixPath('GSM5835471_ChIP_H3K27ac_E125_FB_rep1.narrowPeak.gz'),
#  PosixPath('GSM6152752_ATAC_E125_FB_rep1.narrowPeak.gz'),
#  PosixPath('GSM6152755_ATAC_E125_WP_rep2.narrowPeak.gz'),
#  PosixPath('GSM6152754_ATAC_E125_WP_rep1.narrowPeak.gz'),
#  PosixPath('GSM5835476_ChIP_H3K27ac_E85_PT_rep2.narrowPeak.gz'),
#  PosixPath('GSM5835482_ChIP_H3K27ac_HH35_DS_rep2.narrowPeak.gz'),
#  PosixPath('GSM5835481_ChIP_H3K27ac_HH35_DS_rep1.narrowPeak.gz'),
#  PosixPath('GSM6152757_ATAC_HH19_PT_rep2.narrowPeak.gz'),
#  PosixPath('GSM5835480_ChIP_H3K27ac_HH28_PFL_rep1.narrowPeak.gz'),
#  PosixPath('GSM5835475_ChIP_H3K27ac_E85_PT_rep1.narrowPeak.gz'),
#  PosixPath('GSM6152761_ATAC_HH35_FB_rep2.narrowPeak.gz'),
#  PosixPath('GSM6152760_ATAC_HH35_FB_rep1.narrowPeak.gz'),
#  PosixPath('GSM5835472_ChIP_H3K27ac_E125_PFL_rep1.narrowPeak.gz'),
#  PosixPath('GSM6152756_ATAC_HH19_PT_rep1.narrowPeak.gz'),
#  PosixPath('GSM5835483_ChIP_H3K27ac_HH35_FB_rep1.narrowPeak.gz'),
#  PosixPath('GSM5835473_ChIP_H3K27ac_E125_WP_rep1.narrowPeak.gz'),
#  PosixPath('GSM6152751_ATAC_E95_PT_rep2.narrowPeak.gz')]

# %%
def get_meta(m): 
    return [ m.group(i) for i in [1,2,3,4] ]

matches = [ 
    get_meta(re.search(r"([A-Za-z0-9]+)_([A-Z]+)([0-9]+)_([A-Z]+)_rep[1-2].narrowPeak.gz", str(f)))
    for f in files ]
sample_meta = pd.DataFrame(matches, columns = ["assay", "species", "stage", "tissue"])
sample_meta["file"] = files

mapping_dict = {
    "PT" : "posterior_trunk", 
    "PFL" : "proximal_forelimb",
    "DFL" : "distal_forelimb",
    "FB" : "forebrain",
    "WP" : "whisker_pad",
    "DS" : "dorsal_skin"
}
sample_meta["tissue"] = sample_meta["tissue"].apply(lambda x: mapping_dict.get(x, x)) 

sample_meta["species"] = sample_meta["species"].map({
    "HH" : "gallus_gallus", 
    "E" : "mus_musculus"
})
sample_meta
# Out:
#       assay        species stage             tissue  \
# 0   H3K27ac  gallus_gallus    18    posterior_trunk
# 1      ATAC  gallus_gallus    35        dorsal_skin
# 2      ATAC   mus_musculus   125          forebrain
# 3   H3K27ac  gallus_gallus    28    distal_forelimb
# 4      ATAC  gallus_gallus    35        dorsal_skin
# 5   H3K27ac  gallus_gallus    18    posterior_trunk
# 6   H3K27ac   mus_musculus   125    distal_forelimb
# 7      ATAC   mus_musculus    95    posterior_trunk
# 8   H3K27ac   mus_musculus   125          forebrain
# 9      ATAC   mus_musculus   125          forebrain
# 10     ATAC   mus_musculus   125        whisker_pad
# 11     ATAC   mus_musculus   125        whisker_pad
# 12  H3K27ac   mus_musculus    85    posterior_trunk
# 13  H3K27ac  gallus_gallus    35        dorsal_skin
# 14  H3K27ac  gallus_gallus    35        dorsal_skin
# 15     ATAC  gallus_gallus    19    posterior_trunk
# 16  H3K27ac  gallus_gallus    28  proximal_forelimb
# 17  H3K27ac   mus_musculus    85    posterior_trunk
# 18     ATAC  gallus_gallus    35          forebrain
# 19     ATAC  gallus_gallus    35          forebrain
# 20  H3K27ac   mus_musculus   125  proximal_forelimb
# 21     ATAC  gallus_gallus    19    posterior_trunk
# 22  H3K27ac  gallus_gallus    35          forebrain
# 23  H3K27ac   mus_musculus   125        whisker_pad
# 24     ATAC   mus_musculus    95    posterior_trunk
#
#                                                  file
# 0   GSM5835477_ChIP_H3K27ac_HH18_PT_rep1.narrowPea...
# 1          GSM6152758_ATAC_HH35_DS_rep1.narrowPeak.gz
# 2          GSM6152753_ATAC_E125_FB_rep2.narrowPeak.gz
# 3   GSM5835479_ChIP_H3K27ac_HH28_DFL_rep1.narrowPe...
# 4          GSM6152759_ATAC_HH35_DS_rep2.narrowPeak.gz
# 5   GSM5835478_ChIP_H3K27ac_HH18_PT_rep2.narrowPea...
# 6   GSM5835470_ChIP_H3K27ac_E125_DFL_rep1.narrowPe...
# 7           GSM6152750_ATAC_E95_PT_rep1.narrowPeak.gz
# 8   GSM5835471_ChIP_H3K27ac_E125_FB_rep1.narrowPea...
# 9          GSM6152752_ATAC_E125_FB_rep1.narrowPeak.gz
# 10         GSM6152755_ATAC_E125_WP_rep2.narrowPeak.gz
# 11         GSM6152754_ATAC_E125_WP_rep1.narrowPeak.gz
# 12  GSM5835476_ChIP_H3K27ac_E85_PT_rep2.narrowPeak.gz
# 13  GSM5835482_ChIP_H3K27ac_HH35_DS_rep2.narrowPea...
# 14  GSM5835481_ChIP_H3K27ac_HH35_DS_rep1.narrowPea...
# 15         GSM6152757_ATAC_HH19_PT_rep2.narrowPeak.gz
# 16  GSM5835480_ChIP_H3K27ac_HH28_PFL_rep1.narrowPe...
# 17  GSM5835475_ChIP_H3K27ac_E85_PT_rep1.narrowPeak.gz
# 18         GSM6152761_ATAC_HH35_FB_rep2.narrowPeak.gz
# 19         GSM6152760_ATAC_HH35_FB_rep1.narrowPeak.gz
# 20  GSM5835472_ChIP_H3K27ac_E125_PFL_rep1.narrowPe...
# 21         GSM6152756_ATAC_HH19_PT_rep1.narrowPeak.gz
# 22  GSM5835483_ChIP_H3K27ac_HH35_FB_rep1.narrowPea...
# 23  GSM5835473_ChIP_H3K27ac_E125_WP_rep1.narrowPea...
# 24          GSM6152751_ATAC_E95_PT_rep2.narrowPeak.gz

# %%
unique = sample_meta[ ["assay", "tissue", "stage", "species"] ].drop_duplicates()
unique.shape
# Out:
# (16, 4)

# %%
import shutil
import time

column_names = [
    'chrom', 'start', 'end', 'name', 'score', 'strand',
    'signalValue', 'pValue', 'qValue', 'peak'
]
outdir = Path("merged")
outdir.mkdir(parents=True, exist_ok=True)

og_files = []
out_files = []
for i in range(unique.shape[0]):
    start_time = time.time()
    tissue = unique["tissue"].iloc[i]
    assay = unique["assay"].iloc[i]
    species = unique["species"].iloc[i]
    stage = unique["stage"].iloc[i]
    
    files = sample_meta.loc[ 
        (sample_meta["tissue"] == tissue) & 
        (sample_meta["assay"] == assay) & 
        (sample_meta["stage"] == stage) &
        (sample_meta["species"] == species), 
        "file"]
    outfile = f"{tissue}_{stage}_{assay}_{species}.bed.gz"
    df_all = pd.concat(
                [ pd.read_csv(g, sep='\t', header=None, names=column_names) 
                 for g in files ],
                axis=0)
    merged = merge_intervals(df_all)
    merged.to_csv(outdir / outfile, sep = "\t", index = False, header = False)
    out_files.append(outfile)
    og_files.append(",".join(files.astype(str)))
    print(f"{tissue} {assay} {species} done, took {time.time()-start_time}")
# Out:
# posterior_trunk H3K27ac gallus_gallus done, took 10.836852312088013
# dorsal_skin ATAC gallus_gallus done, took 23.11153531074524
# forebrain ATAC mus_musculus done, took 29.122607469558716
# distal_forelimb H3K27ac gallus_gallus done, took 5.106316566467285
# distal_forelimb H3K27ac mus_musculus done, took 5.064899921417236
# posterior_trunk ATAC mus_musculus done, took 23.96013903617859
# forebrain H3K27ac mus_musculus done, took 5.074098348617554
# whisker_pad ATAC mus_musculus done, took 30.63923668861389
# posterior_trunk H3K27ac mus_musculus done, took 13.5990629196167
# dorsal_skin H3K27ac gallus_gallus done, took 2.4971776008605957
# posterior_trunk ATAC gallus_gallus done, took 29.184200763702393
# proximal_forelimb H3K27ac gallus_gallus done, took 4.653214931488037
# forebrain ATAC gallus_gallus done, took 29.317896127700806
# proximal_forelimb H3K27ac mus_musculus done, took 6.040230751037598
# forebrain H3K27ac gallus_gallus done, took 0.9347119331359863
# whisker_pad H3K27ac mus_musculus done, took 7.407495737075806

# %%
unique["filename"] = out_files
unique["original"] = og_files
unique
# Out:
#       assay             tissue stage        species  \
# 0   H3K27ac    posterior_trunk    18  gallus_gallus
# 1      ATAC        dorsal_skin    35  gallus_gallus
# 2      ATAC          forebrain   125   mus_musculus
# 3   H3K27ac    distal_forelimb    28  gallus_gallus
# 6   H3K27ac    distal_forelimb   125   mus_musculus
# 7      ATAC    posterior_trunk    95   mus_musculus
# 8   H3K27ac          forebrain   125   mus_musculus
# 10     ATAC        whisker_pad   125   mus_musculus
# 12  H3K27ac    posterior_trunk    85   mus_musculus
# 13  H3K27ac        dorsal_skin    35  gallus_gallus
# 15     ATAC    posterior_trunk    19  gallus_gallus
# 16  H3K27ac  proximal_forelimb    28  gallus_gallus
# 18     ATAC          forebrain    35  gallus_gallus
# 20  H3K27ac  proximal_forelimb   125   mus_musculus
# 22  H3K27ac          forebrain    35  gallus_gallus
# 23  H3K27ac        whisker_pad   125   mus_musculus
#
#                                              filename  \
# 0     posterior_trunk_18_H3K27ac_gallus_gallus.bed.gz
# 1            dorsal_skin_35_ATAC_gallus_gallus.bed.gz
# 2              forebrain_125_ATAC_mus_musculus.bed.gz
# 3     distal_forelimb_28_H3K27ac_gallus_gallus.bed.gz
# 6     distal_forelimb_125_H3K27ac_mus_musculus.bed.gz
# 7         posterior_trunk_95_ATAC_mus_musculus.bed.gz
# 8           forebrain_125_H3K27ac_mus_musculus.bed.gz
# 10           whisker_pad_125_ATAC_mus_musculus.bed.gz
# 12     posterior_trunk_85_H3K27ac_mus_musculus.bed.gz
# 13        dorsal_skin_35_H3K27ac_gallus_gallus.bed.gz
# 15       posterior_trunk_19_ATAC_gallus_gallus.bed.gz
# 16  proximal_forelimb_28_H3K27ac_gallus_gallus.bed.gz
# 18             forebrain_35_ATAC_gallus_gallus.bed.gz
# 20  proximal_forelimb_125_H3K27ac_mus_musculus.bed.gz
# 22          forebrain_35_H3K27ac_gallus_gallus.bed.gz
# 23        whisker_pad_125_H3K27ac_mus_musculus.bed.gz
#
#                                              original
# 0   GSM5835477_ChIP_H3K27ac_HH18_PT_rep1.narrowPea...
# 1   GSM6152758_ATAC_HH35_DS_rep1.narrowPeak.gz,GSM...
# 2   GSM6152753_ATAC_E125_FB_rep2.narrowPeak.gz,GSM...
# 3   GSM5835479_ChIP_H3K27ac_HH28_DFL_rep1.narrowPe...
# 6   GSM5835470_ChIP_H3K27ac_E125_DFL_rep1.narrowPe...
# 7   GSM6152750_ATAC_E95_PT_rep1.narrowPeak.gz,GSM6...
# 8   GSM5835471_ChIP_H3K27ac_E125_FB_rep1.narrowPea...
# 10  GSM6152755_ATAC_E125_WP_rep2.narrowPeak.gz,GSM...
# 12  GSM5835476_ChIP_H3K27ac_E85_PT_rep2.narrowPeak...
# 13  GSM5835482_ChIP_H3K27ac_HH35_DS_rep2.narrowPea...
# 15  GSM6152757_ATAC_HH19_PT_rep2.narrowPeak.gz,GSM...
# 16  GSM5835480_ChIP_H3K27ac_HH28_PFL_rep1.narrowPe...
# 18  GSM6152761_ATAC_HH35_FB_rep2.narrowPeak.gz,GSM...
# 20  GSM5835472_ChIP_H3K27ac_E125_PFL_rep1.narrowPe...
# 22  GSM5835483_ChIP_H3K27ac_HH35_FB_rep1.narrowPea...
# 23  GSM5835473_ChIP_H3K27ac_E125_WP_rep1.narrowPea...

# %%
unique["tissue"] = unique["tissue"].astype(str) + "_" + unique["stage"].astype(str)
unique
# Out:
#       assay                 tissue stage        species  \
# 0   H3K27ac     posterior_trunk_18    18  gallus_gallus
# 1      ATAC         dorsal_skin_35    35  gallus_gallus
# 2      ATAC          forebrain_125   125   mus_musculus
# 3   H3K27ac     distal_forelimb_28    28  gallus_gallus
# 6   H3K27ac    distal_forelimb_125   125   mus_musculus
# 7      ATAC     posterior_trunk_95    95   mus_musculus
# 8   H3K27ac          forebrain_125   125   mus_musculus
# 10     ATAC        whisker_pad_125   125   mus_musculus
# 12  H3K27ac     posterior_trunk_85    85   mus_musculus
# 13  H3K27ac         dorsal_skin_35    35  gallus_gallus
# 15     ATAC     posterior_trunk_19    19  gallus_gallus
# 16  H3K27ac   proximal_forelimb_28    28  gallus_gallus
# 18     ATAC           forebrain_35    35  gallus_gallus
# 20  H3K27ac  proximal_forelimb_125   125   mus_musculus
# 22  H3K27ac           forebrain_35    35  gallus_gallus
# 23  H3K27ac        whisker_pad_125   125   mus_musculus
#
#                                              filename  \
# 0     posterior_trunk_18_H3K27ac_gallus_gallus.bed.gz
# 1            dorsal_skin_35_ATAC_gallus_gallus.bed.gz
# 2              forebrain_125_ATAC_mus_musculus.bed.gz
# 3     distal_forelimb_28_H3K27ac_gallus_gallus.bed.gz
# 6     distal_forelimb_125_H3K27ac_mus_musculus.bed.gz
# 7         posterior_trunk_95_ATAC_mus_musculus.bed.gz
# 8           forebrain_125_H3K27ac_mus_musculus.bed.gz
# 10           whisker_pad_125_ATAC_mus_musculus.bed.gz
# 12     posterior_trunk_85_H3K27ac_mus_musculus.bed.gz
# 13        dorsal_skin_35_H3K27ac_gallus_gallus.bed.gz
# 15       posterior_trunk_19_ATAC_gallus_gallus.bed.gz
# 16  proximal_forelimb_28_H3K27ac_gallus_gallus.bed.gz
# 18             forebrain_35_ATAC_gallus_gallus.bed.gz
# 20  proximal_forelimb_125_H3K27ac_mus_musculus.bed.gz
# 22          forebrain_35_H3K27ac_gallus_gallus.bed.gz
# 23        whisker_pad_125_H3K27ac_mus_musculus.bed.gz
#
#                                              original
# 0   GSM5835477_ChIP_H3K27ac_HH18_PT_rep1.narrowPea...
# 1   GSM6152758_ATAC_HH35_DS_rep1.narrowPeak.gz,GSM...
# 2   GSM6152753_ATAC_E125_FB_rep2.narrowPeak.gz,GSM...
# 3   GSM5835479_ChIP_H3K27ac_HH28_DFL_rep1.narrowPe...
# 6   GSM5835470_ChIP_H3K27ac_E125_DFL_rep1.narrowPe...
# 7   GSM6152750_ATAC_E95_PT_rep1.narrowPeak.gz,GSM6...
# 8   GSM5835471_ChIP_H3K27ac_E125_FB_rep1.narrowPea...
# 10  GSM6152755_ATAC_E125_WP_rep2.narrowPeak.gz,GSM...
# 12  GSM5835476_ChIP_H3K27ac_E85_PT_rep2.narrowPeak...
# 13  GSM5835482_ChIP_H3K27ac_HH35_DS_rep2.narrowPea...
# 15  GSM6152757_ATAC_HH19_PT_rep2.narrowPeak.gz,GSM...
# 16  GSM5835480_ChIP_H3K27ac_HH28_PFL_rep1.narrowPe...
# 18  GSM6152761_ATAC_HH35_FB_rep2.narrowPeak.gz,GSM...
# 20  GSM5835472_ChIP_H3K27ac_E125_PFL_rep1.narrowPe...
# 22  GSM5835483_ChIP_H3K27ac_HH35_FB_rep1.narrowPea...
# 23  GSM5835473_ChIP_H3K27ac_E125_WP_rep1.narrowPea...

# %%
meta = unique[["tissue","assay","species","filename","original"]]
meta.to_csv("meta.tsv", sep="\t", index=False)
