# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path
import re
import sys

column_names = [
    'chrom', 'start', 'end', 'name', 'score', 'strand',
    'signalValue', 'pValue', 'qValue', 'peak'
]

dat = pd.read_csv(
    "GSM5623635_ATAC-seq_forelimb_E12stg30_monDom5_wt_Rep1_L18842.cpm.narrow_peak.gz", 
    sep='\t', 
    header=None, 
    names=column_names) 

dat
# Out:
#                                                chrom       start         end  \
# 0  track type=narrowPeak name="GSE185775//GSM5623...         NaN         NaN
# 1                                              chrUn  50636020.0  50636540.0
# 2                                              chrUn  67399770.0  67400030.0
# 3                                              chrUn  67401560.0  67402220.0
#
#                                                 name  score strand  \
# 0                                                NaN    NaN    NaN
# 1  GSE185775//GSM5623635_ATAC-seq_forelimb_E12stg...  187.0      .
# 2  GSE185775//GSM5623635_ATAC-seq_forelimb_E12stg...   91.0      .
# 3  GSE185775//GSM5623635_ATAC-seq_forelimb_E12stg...  138.0      .
#
#    signalValue  pValue  qValue   peak
# 0          NaN     NaN     NaN    NaN
# 1          0.0     0.0     0.0   95.0
# 2          0.0     0.0     0.0   45.0
# 3          0.0     0.0     0.0  175.0
